# %% [markdown]
# https://physionet.org/content/challenge-2017/1.0.0/

# %%
from data.single_lead.data_reader import DataReader
import matplotlib.pyplot as plt

# %%
reader = DataReader(path="../data/single_lead/training2017")

# %%
ds = reader.get_dataset()

# %%
num = 100
plt.plot(ds[num].x.squeeze(), label=ds[num].y)
plt.legend()
plt.show()

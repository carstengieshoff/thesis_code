# %% [markdown]
# https://physionet.org/content/challenge-2017/1.0.0/

# %%
from data_handling.physionet_reader import PhysioNetReader
import matplotlib.pyplot as plt

# %%
reader = PhysioNetReader(path="../data/single_lead/physionet_challenge/training2017")

# %%
# %%time
ds = reader.get_dataset()
# Out:
# CPU times: user 2.93 s, sys: 1.74 s, total: 4.67 s
# Wall time: 6.19 s

# %%
for num in [6, 10, 20]:
    plt.plot(ds[num].x.squeeze(), label=ds[num].y)
    plt.legend()
    plt.show()

# %%
lenghts = [d.x.shape[1] for d in ds]
plt.hist(lenghts, bins = 200)
plt.show()

# %%
len(ds)
# Out:
# 8528

# %%
type(ds[0].y)
# Out:
# str
